# %%
# test_labels.py
from label_generator import create_label_image
from PIL import Image, ImageOps

rows = [
    {"Sku":"BRL0001", "Product": "Hayati Pro Max+ 6K Prefilled Replacement Pods [Blue Razz / 20mg]"},
    {"Sku":"HPMBI20-PP", "Product": "Hayati Pro Max+ 6K Prefilled Replacement Pods", "Flavour":"Banana Ice", "Strength":"20mg"},
    {"Sku":"HPMBCC20-PP", "Product": "Hayati Pro Max+ 6K Prefilled Replacement Pods [Blueberry Cherry Cranberry / 20mg]"},
]

paths = []
for i, r in enumerate(rows):
    p = create_label_image(r, idx=f"test_{i}", label_cm=10.0, dpi=300, return_image=False)
    print("Created:", p)
    paths.append(p)

# To preview quickly in a notebook, use PIL.Image.open on these paths
for p in paths:
    img = Image.open(p)
    display(img.resize((600,600)))
# Out:
# Created: labels/final_labels/label_test_0.png
# Created: labels/final_labels/label_test_1.png
# Created: labels/final_labels/label_test_2.png
# <PIL.Image.Image image mode=RGB size=600x600>
# <PIL.Image.Image image mode=RGB size=600x600>
# <PIL.Image.Image image mode=RGB size=600x600>
